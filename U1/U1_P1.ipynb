# %% [markdown]
# <a href="https://colab.research.google.com/github/KlGamers/Probabilidad-y-Estadistica/blob/main/U1/U1_P1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadistica
#
# ##Unidad 1
#
# ### Facilitador: José Gabriel Rodriguez Rivas
# ### Alumno: Sebastián Villa Bernal
# ### **Programa 1: Estadistica básica e histogramas**

# %%
from statistics import *

ga = [70, 80, 84, 90, 67, 87, 90, 98, 78, 76, 96]
print("La lista de calificaciones del primer grupo es: " + str(ga))
print("La media de la lista del grupo es: ", sum(ga)/len(ga))
print("La mediana de la lista del grupo es: ", median(ga))
print("La moda de la lista del grupo es: ", mode(ga))
print("La varianza de la lista del grupo es: ", variance(ga))
print("El rango de la lista del grupo es: ", max(ga) - min(ga))
print("Los cuartiles de la lista del grupo son: ", quantiles(ga, n=4))
print("La desviación estandar de la lista del grupo es: ", stdev(ga))
# Out:
# La lista de calificaciones del primer grupo es: [70, 80, 84, 90, 67, 87, 90, 98, 78, 76, 96]
# La media de la lista del grupo es:  83.27272727272727
# La mediana de la lista del grupo es:  84
# La moda de la lista del grupo es:  90
# La varianza de la lista del grupo es:  101.61818181818182
# El rango de la lista del grupo es:  31
# Los cuartiles de la lista del grupo son:  [76.0, 84.0, 90.0]
# La desviación estandar de la lista del grupo es:  10.080584398643852

# %%
from statistics import *

t = [16.90, 28.90, 12.43, 25.54, 22.46, 30.3, 9.78, 3.45, 18.98]
print("La lista de los tiempos de la carrera de 100mts es: " + str(t))

print("La media de los tiempos es: ", sum(ga)/len(ga))

print("La mediana de los tiempos es: ", median(ga))

print("La moda de los tiempos es: ", mode(ga))

print("La varianza de los tiempos es: ", variance(ga))

print("El rango de los tiempos es: ", max(ga) - min(ga))

print("Los cuartiles de los tiempos son: ", quantiles(ga, n=4))

print("La desviación estandar de los tiempos es: ", stdev(ga))
# Out:
# La lista de los tiempos de la carrera de 100mts es: [16.9, 28.9, 12.43, 25.54, 22.46, 30.3, 9.78, 3.45, 18.98]
# La media de los tiempos es:  83.27272727272727
# La mediana de los tiempos es:  84
# La moda de los tiempos es:  90
# La varianza de los tiempos es:  101.61818181818182
# El rango de los tiempos es:  31
# Los cuartiles de los tiempos son:  [76.0, 84.0, 90.0]
# La desviación estandar de los tiempos es:  10.080584398643852

# %%
import random

f1=[]
for i in range(100):
  na = round(random.uniform(50, 100), 2)
  f1.append(na)
print(' '.join(map(str, f1)))
# Out:
# 78.71 99.57 84.34 84.85 81.44 93.61 56.68 68.06 81.59 89.48 82.53 91.28 86.1 67.16 57.94 99.71 60.0 99.97 65.01 53.46 55.72 87.27 94.68 59.83 61.76 82.7 51.04 50.98 97.36 51.31 88.04 58.26 93.84 77.62 68.62 75.27 51.23 62.15 50.41 93.8 88.59 77.14 96.86 71.77 98.64 81.09 67.2 55.9 84.01 99.64 64.27 61.84 90.63 64.09 94.85 54.08 62.4 82.45 54.83 68.78 71.66 62.36 54.8 73.0 76.51 87.29 76.88 67.53 77.72 74.46 98.65 68.91 99.68 88.43 71.68 69.19 94.62 64.73 69.6 77.31 88.72 56.43 88.18 94.72 57.7 83.36 81.04 94.74 63.04 76.75 94.3 72.8 79.46 53.17 95.27 96.27 54.78 97.98 67.94 84.37

# %%
import random

f2=[]
for i in range(100):
  na = round(random.uniform(70, 100), 2)
  f2.append(na)
print(' '.join(map(str, f2)))
# Out:
# 75.62 74.0 85.68 73.95 94.75 88.5 88.02 83.57 89.49 84.81 98.61 75.52 92.76 93.29 82.0 79.16 90.61 85.08 86.81 95.6 87.48 76.59 92.93 79.45 79.4 97.19 89.03 95.66 91.51 96.56 78.21 90.88 74.99 76.64 95.42 70.14 91.18 84.6 96.39 97.54 96.11 73.41 93.71 75.52 81.41 90.31 92.47 87.87 86.18 83.28 73.84 83.82 75.31 86.42 76.86 90.19 82.31 78.16 82.14 85.12 80.69 88.89 90.27 80.23 85.01 74.06 87.48 98.14 74.86 72.05 89.64 90.74 87.01 89.83 89.71 89.44 77.3 85.09 96.49 99.58 81.62 76.71 78.25 89.8 75.64 86.03 82.99 77.03 80.28 81.53 97.96 79.0 71.84 75.45 77.25 86.77 79.63 83.71 96.33 75.07

# %%
import matplotlib.pyplot as plt

plt.hist(f1)
plt.title("Producción diaria de la fábrica 1: ")

print("La media es: ", sum(f1)/len(f1))

print("La mediana es: ", median(f1))

print("La moda es: ", mode(f1))

print("La varianza es: ", variance(f1))

print("El rango es: ", max(f1) - min(f1))

print("Los cuartiles son: ", quantiles(f1, n=4))

print("La desviación estandar es: ", stdev(f1))
# Out:
# La media es:  76.1847
# La mediana es:  77.00999999999999
# La moda es:  78.71
# La varianza es:  230.02167566666668
# El rango es:  49.56
# Los cuartiles son:  [62.559999999999995, 77.00999999999999, 88.6875]
# La desviación estandar es:  15.166465496834345

# %%
import matplotlib.pyplot as plt

plt.hist(f2)
plt.title("Producción diaria de la fabrica 2: ")

print("La media es: ", sum(f2)/len(f2))

print("La mediana es: ", median(f2))

print("La moda es: ", mode(f2))

print("La varianza es: ", variance(f2))

print("El rango es: ", max(f2) - min(f2))

print("Los cuartiles son: ", quantiles(f2, n=4))

print("La desviación estandar es: ", stdev(f2))
# Out:
# La media es:  84.93459999999999
# La mediana es:  85.08500000000001
# La moda es:  75.52
# La varianza es:  59.044564484848486
# El rango es:  29.439999999999998
# Los cuartiles son:  [78.1725, 85.08500000000001, 90.535]
# La desviación estandar es:  7.684046101166265

# %%
import matplotlib.pyplot as plt
import random

f1=[]
for i in range(100):
  na = round(random.uniform(50, 100), 2)
  f1.append(na)

f2=[]
for i in range(100):
  na = round(random.uniform(70, 100), 2)
  f2.append(na)

fig, (ax, ax1) = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

ax.hist(f1, bins=10, color='skyblue', edgecolor='black', alpha=0.7)
ax.set_title("Distribución de Producción Diaria - Fábrica 1", fontsize=14)
ax.set_xlabel("Unidades Producidas", fontsize=12)
ax.set_ylabel("Frecuencia", fontsize=12)
ax.grid(axis='y', alpha=0.75)

ax1.hist(f2, bins=10, color='lightcoral', edgecolor='black', alpha=0.7)
ax1.set_title("Distribución de Producción Diaria - Fábrica 2", fontsize=14)
ax1.set_xlabel("Unidades Producidas", fontsize=12)
ax1.set_ylabel("Frecuencia", fontsize=12)
ax1.grid(axis='y', alpha=0.75)

plt.suptitle("Comparación de Producción Diaria entre Fábricas", fontsize=16, y=1.02)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
